# %%
import pandas as pd
import numpy as np

wwpremieres = pd.read_csv("/Users/naomisuzuki/Downloads/westwood movie premieres - the stack - Sheet1.csv")
wwpremieres
# Out:
#                                        Title     Month Day of Week  \
# 0       “Ant-Man and the Wasp: Quantumania”   February      Monday
# 1                          “The Last of Us”   Janurary      Monday
# 2                                 “Joy Ride”      June      Monday
# 3                                     “Air”      March      Monday
# 4   “Are You There, God? It’s Me… Margaret”      April    Saturday
# 5                      “Dungeons & Dragons”      March      Sunday
# 6                                    "Wonka”  December      Sunday
# 7                                     “Leo”   November      Sunday
# 8                      “The Crown: Season 6”  November      Sunday
# 9                             “The Machine”        May    Thursday
# 10            “Never Have I Ever: Season 4”       June    Thursday
# 11              “The Last Thing He Told Me”      March    Thursday
# 12                     “Your Place or Mine”   February    Thursday
# ...

# %%
import matplotlib.pyplot as plt

movies = [2, 2, 4, 1, 4, 1, 0, 2, 1]
shows = [1, 1, 3, 1, 0, 2, 0, 1, 0]
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July-October', 'November', 'December']

plt.bar(months, movies, width = 0.75, color = 'gold', label = 'Movie')
plt.bar(months, shows, bottom = movies, width = 0.75, color = 'royalblue', label = 'TV Show')
plt.legend()
plt.title('Movie vs. TV Show Premieres per Month')
# Out:
# Text(0.5, 1.0, 'Movie vs. TV Show Premieres per Month')
