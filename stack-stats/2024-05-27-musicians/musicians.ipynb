# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import plotly.graph_objects as go
import plotly.express as px
from math import pi

plt.rcParams["font.family"] = "monospace"

# %%
#Monthly Spotify Listeners (in millions)
data = {'Name': ['Sara Bareilles', 'Jim Morrison', '*Nancy Sinatra', '*Conan Gray', '*Anthony Kiedis', 
                 '*Scott Hoying', '*Alec Benjamin', '*Bridgit Mendler', 'Mark McGrath', '*24kGoldn'],
        'Listeners': [5.8, 11.3, 7.3, 24.3, 35.5, 2.9, 22.1, 3.7, 4.7, 14.3],
        'School': ['UCLA','_UCLA', '_UCLA', '_UCLA', '_UCLA',
                   'USC', '_USC', '_USC', '_USC', '_USC'],
        'Color': ['tab:blue', 'tab:blue', 'tab:blue', 'tab:blue', 'tab:blue',
                  'tab:red', 'tab:red', 'tab:red', 'tab:red', 'tab:red']
        }
 
# Create DataFrame
spotify = pd.DataFrame(data)

# Sort from smallest to largest
spotify_sorted = spotify.sort_values('Listeners')

# %%
# Create bars
fig, ax = plt.subplots()
ax.bar(spotify_sorted['Name'], spotify_sorted['Listeners'], label = spotify_sorted['School'], color = spotify_sorted['Color'])
plt.subplots_adjust(bottom=0.1, right=0.9, top=0.8)

# Create axis labels
ax.set_ylabel('Monthly Spotify Listeners (in millions)')
ax.set_title('UCLA vs. USC: Spotify Stats')
plt.setp( ax.xaxis.get_majorticklabels(), rotation=50, ha="right")

# Create legend
ax.legend(title='School')

plt.show()

# %%
# UCLA Radar Plot

# Set data
ucla_film = pd.DataFrame({
'Name': ['John Williams','James Horner','Randy Newman'],
'Golden Globes': [26, 8, 7],
'Grammys': [76, 14, 23],
'Oscars': [56, 10, 22],
'BAFTA': [16, 3, 1],
'Emmys': [9, 0, 3],
})

# ------- PART 1: Create background
 
# number of variable
categories=list(ucla_film)[1:]
N = len(categories)
 
# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]
 
# Initialise the spider plot
ax = plt.subplot(111, polar=True)
 
# If you want the first axis to be on top:
ax.set_theta_offset(pi / 2)
ax.set_theta_direction(-1)

label_loc = np.linspace(start=0, stop=2 * np.pi, num=len(ucla_film[1:5]))
 
# Draw one axe per variable + add labels
plt.xticks(angles[:-1], categories)
 
# Draw ylabels
ax.set_rlabel_position(270)
plt.yticks([20,40,60], ["20","40","60"], color="darkslategray", size=9)
plt.ylim(0,80)
 

# ------- PART 2: Add plots
 
# Plot each individual = each line of the data

# Ind1
values=ucla_film.loc[0].drop('Name').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=2, linestyle='solid', label="John Williams")

# Ind3
values=ucla_film.loc[2].drop('Name').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=2, linestyle='solid', label="Randy Newman")

# Ind2
values=ucla_film.loc[1].drop('Name').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=2, linestyle='solid', label="James Horner")
 
# Add legend
plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))

ax.tick_params(axis='both', which='major', pad=35, labelsize=12)

# Show the graph
plt.show()

# %%
# USC Radar Plot

# Set data
usc_film = pd.DataFrame({
'Name': ['Jerry Goldsmith','James Horner','Thomas Newman'],
'Golden Globes': [9, 8, 4],
'Grammys': [6, 14, 14],
'Oscars': [18, 10, 15],
'BAFTA': [4, 3, 6],
'Emmys': [7, 0, 3],
})

# ------- PART 1: Create background
 
# number of variable
categories=list(usc_film)[1:]
N = len(categories)
 
# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]
 
# Initialise the spider plot
ax = plt.subplot(111, polar=True)
 
# If you want the first axis to be on top:
ax.set_theta_offset(pi / 2)
ax.set_theta_direction(-1)

label_loc = np.linspace(start=0, stop=2 * np.pi, num=len(ucla_film[1:5]))
 
# Draw one axe per variable + add labels
plt.xticks(angles[:-1], categories)
 
# Draw ylabels
ax.set_rlabel_position(270)
plt.yticks([5,10,15], ["5","10","15"], color="darkslategray", size=9)
plt.ylim(0,20)
 

# ------- PART 2: Add plots
 
# Plot each individual = each line of the data

# Ind1
values=usc_film.loc[0].drop('Name').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=2, linestyle='solid', label="Jerry Goldsmith")

# Ind3
values=usc_film.loc[2].drop('Name').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=2, linestyle='solid', label="Thomas Newman")

# Ind2
values=usc_film.loc[1].drop('Name').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=2, linestyle='solid', label="James Horner")
 
# Add legend
plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))

ax.tick_params(axis='both', which='major', pad=35, labelsize=12)

# Show the graph
plt.show()
