# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
plt.rcParams["font.family"] = "monospace"

# %%
boba = pd.read_csv('stackstats.boba data  - reorganized.csv')

# %%
boba.head
# Out:
# <bound method NDFrame.head of              Store  Standard_Price                    Cheapest_Name  \
# 0        Just Boba            5.75                       Brewed Tea
# 1   It's Boba Time            6.30                       Teaspresso
# 2            Junbi            6.34  Americano or Matcha Straight Up
# 3         Sharetea            8.11          Classic Oolong Milk Tea
# 4       Meet Fresh            6.00                     Classic Teas
# 5  Lollipop Fresh             8.25          Classic Green/Black Tea
# 6      Honey Krush            5.50           Americano or Fresh Tea
#
#    Cheapest_Price  Total_Drinks  Milk Tea  Tea/Fruit Tea  Blended  Specialty  \
# 0            4.75            53        12             18       11         12
# 1            4.25           147        32             31       68         16
# 2            4.69            47        20             10        4         13
# 3            5.75            72        27             25        8         12
# ...

# %%
boba_type = boba[['Store', 'Milk Tea', 'Tea/Fruit Tea', 'Blended', 'Specialty']]

# %%
boba_type.plot(x='Store', kind='bar', stacked=True, 
               figsize=(8,5), color=['#E9CA9C', '#8EB166', '#966245', '#391403'], 
               title='Drink Variety of Westwood Boba Shops')
plt.xlabel("Shop");
plt.ylabel("Number of Drinks");
handles, labels = plt.gca().get_legend_handles_labels()
order = [3,2,1,0]
plt.legend([handles[idx] for idx in order],[labels[idx] for idx in order])
plt.xticks(rotation=25);
plt.show()
