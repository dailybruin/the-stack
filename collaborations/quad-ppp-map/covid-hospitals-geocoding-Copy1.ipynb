# %%
import pandas as pd
from mapbox import Geocoder

# %%
geocoder = Geocoder(access_token="pk.eyJ1IjoiamVycnlsaW5ldyIsImEiOiJjajIwc2E1YXkwMmt6MzNuMXZnaWRjb2lhIn0.u0AHZNQd8_8hFmpaVvI1nQ")

# %%
df = pd.read_csv("westwood_ppp_small.csv")
df
# Out:
#               LoanRange                                       BusinessName  \
# 0       a $5-10 million                  WOOD, SMITH, HENNING & BERMAN LLP
# 1        b $2-5 million  ARMAND HAMMER ART MUSEUM AND CULTURAL CENTER, ...
# 2        b $2-5 million                           GREEN HASSON & JANKS LLP
# 3        b $2-5 million                              IRONGATE AZREP BW LLC
# 4        b $2-5 million          LAMONICA'S PIZZA DOUGH INTERNATIONAL, LLC
# ..                  ...                                                ...
# 164  e $150,000-350,000                           WILLIAM C. KIM MD., INC.
# 165  e $150,000-350,000             WILSHIRE HOLMBY HOMEOWNERS ASSOC. INC.
# 166  e $150,000-350,000            WILSHIRE MANNING HOMEOWNERS ASSOCIATION
# 167  e $150,000-350,000                                      WISERCARE INC
# 168  e $150,000-350,000                           YAGOUBZADEH LAW FIRM LLP
#
#                             Address  JobsRetained
# 0         10960 WILSHIRE BLVD Fl 18           NaN
# 1               10899 WILSHIRE BLVD         173.0
# 2              10990 WILSHIRE BLVD.         146.0
# 3    10877 WILSHIRE BLVD Suite 2300         324.0
# 4                   1066 Gayley Ave         163.0
# ..                              ...           ...
# 164                  321 CONWAY AVE          18.0
# 165            10433 WILSHIRE BLVD.          26.0
# 166        10660 Wilshire Boulevard           NaN
# 167    10880 WILSHIRE BLVD STE 2240          11.0
# 168     10866 WILSHIRE BLVD STE 600          26.0
#
# [169 rows x 4 columns]

# %%
a = df.iloc[0]["Address"]
a
# Out:
# '10960 WILSHIRE BLVD Fl 18'

# %%
response = geocoder.forward(a).json()
response
# Out:
# {'type': 'FeatureCollection',
#  'query': ['10960', 'wilshire', 'blvd', 'fl', '18'],
#  'features': [{'id': 'address.9004597105461942',
#    'type': 'Feature',
#    'place_type': ['address'],
#    'relevance': 1,
#    'properties': {'accuracy': 'rooftop'},
#    'text': 'Wilshire Boulevard',
#    'place_name': '10960 Wilshire Boulevard, Los Angeles, California 90024, United States',
#    'center': [-118.445973, 34.057997],
#    'geometry': {'type': 'Point', 'coordinates': [-118.445973, 34.057997]},
#    'address': '10960',
#    'context': [{'id': 'neighborhood.289327', 'text': 'Westwood'},
#     {'id': 'postcode.16189083794443910', 'text': '90024'},
#     {'id': 'place.7397503093427640', 'wikidata': 'Q65', 'text': 'Los Angeles'},
#     {'id': 'region.9803118085738010',
#      'wikidata': 'Q99',
#      'short_code': 'US-CA',
#      'text': 'California'},
#     {'id': 'country.19678805456372290',
#      'short_code': 'us',
#      'wikidata': 'Q30',
#      'text': 'United States'}]},
#   {'id': 'address.4089824497903944',
#    'type': 'Feature',
#    'place_type': ['address'],
#    'relevance': 1,
#    'properties': {'accuracy': 'parcel'},
#    'text': 'Wilshire Boulevard',
#    'place_name': '10960 Wilshire Boulevard, Lake Toxaway, North Carolina 28747, United States',
#    'center': [-82.894057, 35.159152],
#    'geometry': {'type': 'Point', 'coordinates': [-82.894057, 35.159152]},
#    'address': '10960',
#    'context': [{'id': 'postcode.15112857579332800', 'text': '28747'},
#     {'id': 'place.8605343911403350',
#      'wikidata': 'Q6478137',
#      'text': 'Lake Toxaway'},
#     {'id': 'region.7109819773854480',
#      'wikidata': 'Q1454',
#      'short_code': 'US-NC',
#      'text': 'North Carolina'},
#     {'id': 'country.19678805456372290',
#      'short_code': 'us',
#      'wikidata': 'Q30',
#      'text': 'United States'}]},
#   {'id': 'address.2843115485081996',
#    'type': 'Feature',
#    'place_type': ['address'],
#    'relevance': 1,
#    'properties': {'accuracy': 'interpolated'},
#    'text': 'Wilshire Lane',
#    'place_name': '10960 Wilshire Lane, Coos Bay, Oregon 97420, United States',
#    'matching_text': 'Wilshire Blvd',
#    'matching_place_name': '10960 Wilshire Blvd, Coos Bay, Oregon 97420, United States',
#    'center': [-124.313522, 43.345956],
#    'geometry': {'type': 'Point',
#     'coordinates': [-124.313522, 43.345956],
#     'interpolated': True},
#    'address': '10960',
#    'context': [{'id': 'postcode.19048788133844540', 'text': '97420'},
#     {'id': 'place.15289896550666100',
#      'wikidata': 'Q913266',
#      'text': 'Coos Bay'},
#     {'id': 'region.9993399217164570',
#      'wikidata': 'Q824',
#      'short_code': 'US-OR',
#      'text': 'Oregon'},
#     {'id': 'country.19678805456372290',
#      'short_code': 'us',
#      'wikidata': 'Q30',
#      'text': 'United States'}]},
#   {'id': 'address.911687503982458',
#    'type': 'Feature',
#    'place_type': ['address'],
#    'relevance': 0.99,
#    'properties': {'accuracy': 'street'},
#    'text': 'Wilshire Blvd',
#    'place_name': 'Wilshire Blvd, Biloxi, Mississippi 39531, United States',
#    'center': [-88.9897733, 30.3994661],
#    'geometry': {'type': 'Point', 'coordinates': [-88.9897733, 30.3994661]},
#    'context': [{'id': 'neighborhood.299003', 'text': 'West Biloxi'},
#     {'id': 'postcode.15923166310726240', 'text': '39531'},
#     {'id': 'place.13620943381689250', 'wikidata': 'Q490720', 'text': 'Biloxi'},
#     {'id': 'region.8199901647736440',
#      'wikidata': 'Q1494',
#      'short_code': 'US-MS',
#      'text': 'Mississippi'},
#     {'id': 'country.19678805456372290',
#      'short_code': 'us',
#      'wikidata': 'Q30',
#      'text': 'United States'}]},
#   {'id': 'address.3588829412874500',
#    'type': 'Feature',
#    'place_type': ['address'],
#    'relevance': 0.973684,
#    'properties': {'accuracy': 'interpolated'},
#    'text': 'Wilkshire Boulevard Northeast',
#    'place_name': '10960 Wilkshire Boulevard Northeast, Bolivar, Ohio 44612, United States',
#    'center': [-81.444216, 40.639715],
#    'geometry': {'type': 'Point',
#     'coordinates': [-81.444216, 40.639715],
#     'interpolated': True},
#    'address': '10960',
#    'context': [{'id': 'postcode.12256212110175620', 'text': '44612'},
#     {'id': 'place.8356529180130020', 'wikidata': 'Q935564', 'text': 'Bolivar'},
#     {'id': 'region.9595035861229390',
#      'wikidata': 'Q1397',
#      'short_code': 'US-OH',
#      'text': 'Ohio'},
#     {'id': 'country.19678805456372290',
#      'short_code': 'us',
#      'wikidata': 'Q30',
#      'text': 'United States'}]}],
#  'attribution': 'NOTICE: © 2020 Mapbox and its suppliers. All rights reserved. Use of this data is subject to the Mapbox Terms of Service (https://www.mapbox.com/about/maps/). This response and the information it contains may not be retained. POI(s) provided by Foursquare.'}

# %%
df['long'] = df.apply(
     lambda row: 
         geocoder.forward(row.Address).json()['features'][0]['center'][0], axis=1)
df['lat'] = df.apply(
     lambda row: 
         geocoder.forward(row.Address).json()['features'][0]['center'][1], axis=1)
df
# Out:
#               LoanRange                                       BusinessName  \
# 0       a $5-10 million                  WOOD, SMITH, HENNING & BERMAN LLP
# 1        b $2-5 million  ARMAND HAMMER ART MUSEUM AND CULTURAL CENTER, ...
# 2        b $2-5 million                           GREEN HASSON & JANKS LLP
# 3        b $2-5 million                              IRONGATE AZREP BW LLC
# 4        b $2-5 million          LAMONICA'S PIZZA DOUGH INTERNATIONAL, LLC
# ..                  ...                                                ...
# 164  e $150,000-350,000                           WILLIAM C. KIM MD., INC.
# 165  e $150,000-350,000             WILSHIRE HOLMBY HOMEOWNERS ASSOC. INC.
# 166  e $150,000-350,000            WILSHIRE MANNING HOMEOWNERS ASSOCIATION
# 167  e $150,000-350,000                                      WISERCARE INC
# 168  e $150,000-350,000                           YAGOUBZADEH LAW FIRM LLP
#
#                             Address  JobsRetained        long        lat
# 0         10960 WILSHIRE BLVD Fl 18           NaN -118.445973  34.057997
# 1               10899 WILSHIRE BLVD         173.0 -118.443760  34.059060
# 2              10990 WILSHIRE BLVD.         146.0 -118.447776  34.057680
# 3    10877 WILSHIRE BLVD Suite 2300         324.0 -118.442540  34.059340
# 4                   1066 Gayley Ave         163.0 -118.446860  34.060930
# ..                              ...           ...         ...        ...
# 164                  321 CONWAY AVE          18.0  -75.265534  40.008763
# 165            10433 WILSHIRE BLVD.          26.0 -118.430533  34.066393
# 166        10660 Wilshire Boulevard           NaN -118.435290  34.060748
# 167    10880 WILSHIRE BLVD STE 2240          11.0 -118.442830  34.058850
# 168     10866 WILSHIRE BLVD STE 600          26.0 -118.442000  34.059070
#
# [169 rows x 6 columns]

# %%
df.to_csv("westwood_ppp_small_cleaned.csv", index=False)

# %%
from json import load, JSONEncoder
from argparse import ArgumentParser, FileType
from re import compile
import sys

from shapely.geometry import Polygon, mapping
from shapely.ops import cascaded_union

# %%
file = {
    "type": "FeatureCollection",
    "features": [    
        {
            "type": "Feature",
            "properties": {
                "kind": "L.A. County Neighborhood (Current)",
                "external_id": "athens",
                "name": "Athens",
                "slug": "athens-la-county-neighborhood-current",
                "set": "/1.0/boundary-set/la-county-neighborhoods-current/",
                "metadata": {"sqmi": 1.33275332251, "type": "unincorporated-area", "name": "Athens", "slug": "athens"},
                "resource_uri": "/1.0/boundary/athens-la-county-neighborhood-current/"
            },
            "geometry": { "type": "Polygon", "coordinates": [ 
                        [ -118.291663972105155, 33.930963005656039 ], 
                        [ -118.291524972104938, 33.930962005655957 ], 
                        [ -118.291606982357763, 33.916422006214361 ], 
                        [ -118.313912980479031, 33.916452000075033 ], 
                        [ -118.31398199285357, 33.918361003810489 ], 
                        [ -118.315209985025277, 33.918433998438147 ], 
                        [ -118.316483987315152, 33.917656005465453 ], 
                        [ -118.31778797898059, 33.917520003156469 ], 
                        [ -118.317768979862549, 33.921606005763273 ], 
                        [ -118.313390992418448, 33.9234099992319 ], 
                        [ -118.313391986058718, 33.93091200460988 ], 
                        [ -118.291663972105155, 33.930963005656039 ] 
                ] }
        },
        {
            "type": "Feature",
            "properties": {
                "kind": "L.A. County Neighborhood (Current)",
                "external_id": "westmont",
                "name": "Westmont",
                "slug": "westmont-la-county-neighborhood-current",
                "set": "/1.0/boundary-set/la-county-neighborhoods-current/",
                "metadata": {"sqmi": 1.84381583493, "type": "unincorporated-area", "name": "Westmont", "slug": "westmont"},
                "resource_uri": "/1.0/boundary/westmont-la-county-neighborhood-current/"
            },
            "geometry": { "type": "Polygon", "coordinates": [  
                [ -118.292472989872849, 33.95951400322592 ], 
                [ -118.291595982569675, 33.959495004635755 ], 
                [ -118.291524972104938, 33.930962005655957 ], 
                [ -118.317752979089761, 33.930901001647982 ], 
                [ -118.317719982513182, 33.94546299957149 ], 
                [ -118.313371983162199, 33.945460004723991 ], 
                [ -118.313386989551688, 33.938214000142573 ], 
                [ -118.30902499719825, 33.938210004721995 ], 
                [ -118.309014974916209, 33.941833000143951 ], 
                [ -118.305190995504958, 33.941845002911577 ], 
                [ -118.305179974908896, 33.945467000185211 ], 
                [ -118.302453995362868, 33.945474003461399 ], 
                [ -118.302447974911544, 33.949993000109373 ], 
                [ -118.300261995361026, 33.949999003468804 ], 
                [ -118.300266974796259, 33.959481001336009 ], 
                [ -118.292472989872849, 33.95951400322592 ] 
             ] }
        }
    ]
}

polygons = []

for feat in file['features']:
    polygon = Polygon([ (coor[0], coor[1]) for coor in  feat['geometry']['coordinates'] ])
    polygons.append(polygon)

new_geometry = mapping(cascaded_union(polygons)) # This line merges the polygones

new_feature = dict(type='Feature', id="", properties=dict(Name=""),geometry=dict(type=new_geometry['type'], coordinates=new_geometry['coordinates']))

outjson = dict(type='FeatureCollection', features=[new_feature])

encoder = JSONEncoder(separators=(',', ':'))
encoded = encoder.iterencode(outjson)

# output = outfile

for token in encoded:
    print(token)
# Out:
# {
# "type"
# :
# "FeatureCollection"
# ,
# "features"
# :
# [
# {
# "type"
# :
# "Feature"
# ,
# "id"
# :
# ""
# ,
# "properties"
# :
# {
# "Name"
# :
# ""
# }
# ,
# "geometry"
# :
# {
# "type"
# :
# "Polygon"
# ,
# "coordinates"
# :
# [
# [
# [-118.29152497210494
# ,33.93096200565596
# ]
# ,
# [-118.29160698235776
# ,33.91642200621436
# ]
# ,
# [-118.31391298047903
# ,33.91645200007503
# ]
# ,
# [-118.31398199285357
# ,33.91836100381049
# ]
# ,
# [-118.31520998502528
# ,33.91843399843815
# ]
# ,
# [-118.31648398731515
# ,33.91765600546545
# ]
# ,
# [-118.31778797898059
# ,33.91752000315647
# ]
# ,
# [-118.31776897986255
# ,33.92160600576327
# ]
# ,
# [-118.31339099241845
# ,33.9234099992319
# ]
# ,
# [-118.31339198594485
# ,33.93091114492958
# ]
# ,
# [-118.31775297908976
# ,33.93090100164798
# ]
# ,
# [-118.31771998251318
# ,33.94546299957149
# ]
# ,
# [-118.3133719831622
# ,33.94546000472399
# ]
# ,
# [-118.31338698955169
# ,33.93821400014257
# ]
# ,
# [-118.30902499719825
# ,33.938210004721995
# ]
# ,
# [-118.30901497491621
# ,33.94183300014395
# ]
# ,
# [-118.30519099550496
# ,33.94184500291158
# ]
# ,
# [-118.3051799749089
# ,33.94546700018521
# ]
# ,
# [-118.30245399536287
# ,33.9454740034614
# ]
# ,
# [-118.30244797491154
# ,33.94999300010937
# ]
# ,
# [-118.30026199536103
# ,33.949999003468804
# ]
# ,
# [-118.30026697479626
# ,33.95948100133601
# ]
# ,
# [-118.29247298987285
# ,33.95951400322592
# ]
# ,
# [-118.29159598256967
# ,33.959495004635755
# ]
# ,
# [-118.29152497210494
# ,33.93096200565596
# ]
# ]
# ]
# }
# }
# ]
# }

# %%
import json

with open('the-stack/test.geojson', 'r') as f:
    data = json.load(f)

#A Python dictionary containing properties to be added to each GeoJSON Feature
properties_dict={
    "cases": None,
    "population": None
    }
#Convert the dictionary to a list
# properties_list=zip(properties_dict.keys(),properties_dict.values())

#Loop over GeoJSON features and add the new properties
for feat in data['features']:
#     for i in range(len(properties_list)):
    feat['properties'].update(properties_dict)
#         feat ['properties'][properties_list[i][0]]=properties_list[i][1]

#Write result to a new file
with open('the-stack/output.geojson', 'w') as f:
    json.dump(data, f, indent=4)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-00fc2bbdc259> in <module>
#       1 import json
#       2
# ----> 3 with open('the-stack/test.geojson', 'r') as f:
#       4     data = json.load(f)
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: 'the-stack/test.geojson'
