# %%
import pandas as pd
from mapbox import Geocoder

# %%
geocoder = Geocoder(access_token="pk.eyJ1IjoiamVycnlsaW5ldyIsImEiOiJjajIwc2E1YXkwMmt6MzNuMXZnaWRjb2lhIn0.u0AHZNQd8_8hFmpaVvI1nQ")

# %%
df = pd.read_csv("covid-hospitals.csv")
df
# Out:
#                                          Facility Name  \
# 0      City of Hope Helford Clinical Research Hospital
# 1              USC Kenneth Norris, Jr. Cancer Hospital
# 2                             American Recovery Center
# 3                 Tom Redgate Memorial Recovery Center
# 4                         Kindred Hospital - South Bay
# ..                                                 ...
# 114  Star View Adolescent - Pychiatric Health Facility
# 115                           Tarzana Treatment Center
# 116                California Rehabilitation Institute
# 117                               Casa Colina Hospital
# 118  Los Angeles County/Rancho Los Amigos\nNational...
#
#                                        Address  \
# 0               1500 E Duarte Rd\nDuarte 91010
# 1         1441 Eastlake Ave\nLos Angeles 90033
# 2             2180 W Valley Blvd\nPomona 91768
# 3           1775 Chestnut St\nLong Beach 90813
# 4               1246 W 155th St\nGardena 90247
# ..                                         ...
# 114              4025 W 226 St\nTorrance 90505
# 115             18646 Oxnard St\nTarzana 91356
# 116  2070 Century Park East\nLos Angeles 90067
# 117             255 E Bonita Ave\nPomona 91767
# 118          7601 E Imperial Hwy\nDowney 90242
#
#                                    Type Total Beds  \
# 0             Cancer Medical / Surgical        217
# 1             Cancer Medical / Surgical         60
# 2    Chemical Dependency (Alcohol/Drug)         50
# 3    Chemical Dependency (Alcohol/Drug)         63
# 4          General Acute Long-Term Care         54
# ..                                  ...        ...
# 114                         Psychiatric         16
# 115                         Psychiatric         60
# 116                      Rehabilitation        138
# 117                      Rehabilitation         99
# 118                      Rehabilitation        239
#
#     Emergency Medical Service Level(1)  Initial License Year
# 0                                 None                  1946
# 1                                 None                  1983
# 2                                  NaN                  1987
# 3                                  NaN                  1983
# 4                                 None                  1957
# ..                                 ...                   ...
# 114                                NaN                  1996
# 115                                NaN                  1970
# 116                              Basic                  2016
# 117                               None                  1961
# 118                               None                  1966
#
# [119 rows x 6 columns]

# %%
# a = df.iloc[0]["Address"]
# a
# Out:
# '1500 E Duarte Rd\nDuarte 91010'

# %%
# response = geocoder.forward(a).json()
# response
# Out:
# {'type': 'FeatureCollection',
#  'query': ['1500', 'e', 'duarte', 'rd', 'duarte', '91010'],
#  'features': [{'id': 'address.00910103012003',
#    'type': 'Feature',
#    'place_type': ['address'],
#    'relevance': 1,
#    'address': '1500',
#    'text': 'Duarte Rd',
#    'place_name': '1500 Duarte Rd, Duarte, California 91010, United States',
#    'center': [-117.96778, 34.13198],
#    'properties': {'accuracy': 'approximate'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.96778, 34.13198]},
#    'context': [{'id': 'neighborhood.285281', 'text': 'Park Victoria'},
#     {'id': 'postcode.12494698283264290', 'text': '91010'},
#     {'id': 'place.9598200647430870', 'wikidata': 'Q927189', 'text': 'Duarte'},
#     {'id': 'region.9697035897738010',
#      'short_code': 'US-CA',
#      'wikidata': 'Q99',
#      'text': 'California'},
#     {'id': 'country.19352517729256050',
#      'short_code': 'us',
#      'wikidata': 'Q30',
#      'text': 'United States'}]},
#   {'id': 'address.3680550612403794',
#    'type': 'Feature',
#    'place_type': ['address'],
#    'relevance': 0.5075,
#    'properties': {'accuracy': 'interpolated'},
#    'text': 'Duarte Road',
#    'place_name': '1500 Duarte Road, Arcadia, California 91775, United States',
#    'matching_text': 'E Duarte Rd',
#    'matching_place_name': '1500 E Duarte Rd, Arcadia, California 91775, United States',
#    'center': [-118.064676, 34.124652],
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.064676, 34.124652],
#     'interpolated': True},
#    'address': '1500',
#    'context': [{'id': 'neighborhood.31663', 'text': 'East San Gabriel'},
#     {'id': 'postcode.3680550612403794', 'text': '91775'},
#     {'id': 'place.6677785059392840', 'wikidata': 'Q534536', 'text': 'Arcadia'},
#     {'id': 'region.9697035897738010',
#      'short_code': 'US-CA',
#      'wikidata': 'Q99',
#      'text': 'California'},
#     {'id': 'country.19352517729256050',
#      'short_code': 'us',
#      'wikidata': 'Q30',
#      'text': 'United States'}]},
#   {'id': 'address.5789755912235868',
#    'type': 'Feature',
#    'place_type': ['address'],
#    'relevance': 0.506667,
#    'properties': {'accuracy': 'street'},
#    'text': 'East Duarte Road',
#    'place_name': 'East Duarte Road, Monrovia, California 91016, United States',
#    'center': [-117.9943039, 34.1319145],
#    'geometry': {'type': 'Point', 'coordinates': [-117.9943039, 34.1319145]},
#    'context': [{'id': 'neighborhood.285280', 'text': 'Monrovista'},
#     {'id': 'postcode.8667580620978150', 'text': '91016'},
#     {'id': 'place.5882967468916690',
#      'wikidata': 'Q926988',
#      'text': 'Monrovia'},
#     {'id': 'region.9697035897738010',
#      'short_code': 'US-CA',
#      'wikidata': 'Q99',
#      'text': 'California'},
#     {'id': 'country.19352517729256050',
#      'short_code': 'us',
#      'wikidata': 'Q30',
#      'text': 'United States'}]},
#   {'id': 'address.1319538790310456',
#    'type': 'Feature',
#    'place_type': ['address'],
#    'relevance': 0.506667,
#    'properties': {'accuracy': 'street'},
#    'text': 'East Duarte Road',
#    'place_name': 'East Duarte Road, Arcadia, California 91006, United States',
#    'center': [-118.02597809, 34.13034058],
#    'geometry': {'type': 'Point', 'coordinates': [-118.02597809, 34.13034058]},
#    'context': [{'id': 'postcode.7394106484434560', 'text': '91006'},
#     {'id': 'place.6677785059392840', 'wikidata': 'Q534536', 'text': 'Arcadia'},
#     {'id': 'region.9697035897738010',
#      'short_code': 'US-CA',
#      'wikidata': 'Q99',
#      'text': 'California'},
#     {'id': 'country.19352517729256050',
#      'short_code': 'us',
#      'wikidata': 'Q30',
#      'text': 'United States'}]},
#   {'id': 'postcode.12494698283264290',
#    'type': 'Feature',
#    'place_type': ['postcode'],
#    'relevance': 0.493333,
#    'properties': {},
#    'text': '91010',
#    'place_name': 'Duarte, California 91010, United States',
#    'bbox': [-117.999542765031,
#     34.1137600144267,
#     -117.924659059915,
#     34.165511654017],
#    'center': [-117.98, 34.14],
#    'geometry': {'type': 'Point', 'coordinates': [-117.98, 34.14]},
#    'context': [{'id': 'place.9598200647430870',
#      'wikidata': 'Q927189',
#      'text': 'Duarte'},
#     {'id': 'region.9697035897738010',
#      'short_code': 'US-CA',
#      'wikidata': 'Q99',
#      'text': 'California'},
#     {'id': 'country.19352517729256050',
#      'short_code': 'us',
#      'wikidata': 'Q30',
#      'text': 'United States'}]}],
#  'attribution': 'NOTICE: © 2020 Mapbox and its suppliers. All rights reserved. Use of this data is subject to the Mapbox Terms of Service (https://www.mapbox.com/about/maps/). This response and the information it contains may not be retained. POI(s) provided by Foursquare.'}

# %%
# df['long'] = df.apply(
#     lambda row: 
#         geocoder.forward(row.Address).json()['features'][0]['center'][0], axis=1)
# df['lat'] = df.apply(
#     lambda row: 
#         geocoder.forward(row.Address).json()['features'][0]['center'][1], axis=1)
# df
# Out:
#                                          Facility Name  \
# 0      City of Hope Helford Clinical Research Hospital
# 1              USC Kenneth Norris, Jr. Cancer Hospital
# 2                             American Recovery Center
# 3                 Tom Redgate Memorial Recovery Center
# 4                         Kindred Hospital - South Bay
# ..                                                 ...
# 114  Star View Adolescent - Pychiatric Health Facility
# 115                           Tarzana Treatment Center
# 116                California Rehabilitation Institute
# 117                               Casa Colina Hospital
# 118  Los Angeles County/Rancho Los Amigos\nNational...
#
#                                        Address  \
# 0               1500 E Duarte Rd\nDuarte 91010
# 1         1441 Eastlake Ave\nLos Angeles 90033
# 2             2180 W Valley Blvd\nPomona 91768
# 3           1775 Chestnut St\nLong Beach 90813
# 4               1246 W 155th St\nGardena 90247
# ..                                         ...
# 114              4025 W 226 St\nTorrance 90505
# 115             18646 Oxnard St\nTarzana 91356
# 116  2070 Century Park East\nLos Angeles 90067
# 117             255 E Bonita Ave\nPomona 91767
# 118          7601 E Imperial Hwy\nDowney 90242
#
#                                    Type Total Beds  \
# 0             Cancer Medical / Surgical        217
# 1             Cancer Medical / Surgical         60
# 2    Chemical Dependency (Alcohol/Drug)         50
# 3    Chemical Dependency (Alcohol/Drug)         63
# 4          General Acute Long-Term Care         54
# ..                                  ...        ...
# 114                         Psychiatric         16
# 115                         Psychiatric         60
# 116                      Rehabilitation        138
# 117                      Rehabilitation         99
# 118                      Rehabilitation        239
#
#     Emergency Medical Service Level(1)  Initial License Year        long  \
# 0                                 None                  1946 -117.967780
# 1                                 None                  1983 -118.206313
# 2                                  NaN                  1987 -117.790624
# 3                                  NaN                  1983 -118.196440
# 4                                 None                  1957 -118.297401
# ..                                 ...                   ...         ...
# 114                                NaN                  1996 -118.356250
# 115                                NaN                  1970 -118.540270
# 116                              Basic                  2016 -118.412271
# 117                               None                  1961 -117.745743
# 118                               None                  1966 -118.157999
#
#            lat
# 0    34.131980
# 1    34.061179
# 2    34.060670
# 3    33.788460
# 4    33.890004
# ..         ...
# 114  33.824329
# 115  34.179850
# 116  34.059057
# 117  34.096298
# 118  33.929099
#
# [119 rows x 8 columns]

# %%
# df.to_csv("hospital_data.csv", index=False)

# %%
from json import load, JSONEncoder
from argparse import ArgumentParser, FileType
from re import compile
import sys

from shapely.geometry import Polygon, mapping
from shapely.ops import cascaded_union

# %%
file = {
    "type": "FeatureCollection",
    "features": [    
        {
            "type": "Feature",
            "properties": {
                "kind": "L.A. County Neighborhood (Current)",
                "external_id": "athens",
                "name": "Athens",
                "slug": "athens-la-county-neighborhood-current",
                "set": "/1.0/boundary-set/la-county-neighborhoods-current/",
                "metadata": {"sqmi": 1.33275332251, "type": "unincorporated-area", "name": "Athens", "slug": "athens"},
                "resource_uri": "/1.0/boundary/athens-la-county-neighborhood-current/"
            },
            "geometry": { "type": "Polygon", "coordinates": [ 
                        [ -118.291663972105155, 33.930963005656039 ], 
                        [ -118.291524972104938, 33.930962005655957 ], 
                        [ -118.291606982357763, 33.916422006214361 ], 
                        [ -118.313912980479031, 33.916452000075033 ], 
                        [ -118.31398199285357, 33.918361003810489 ], 
                        [ -118.315209985025277, 33.918433998438147 ], 
                        [ -118.316483987315152, 33.917656005465453 ], 
                        [ -118.31778797898059, 33.917520003156469 ], 
                        [ -118.317768979862549, 33.921606005763273 ], 
                        [ -118.313390992418448, 33.9234099992319 ], 
                        [ -118.313391986058718, 33.93091200460988 ], 
                        [ -118.291663972105155, 33.930963005656039 ] 
                ] }
        },
        {
            "type": "Feature",
            "properties": {
                "kind": "L.A. County Neighborhood (Current)",
                "external_id": "westmont",
                "name": "Westmont",
                "slug": "westmont-la-county-neighborhood-current",
                "set": "/1.0/boundary-set/la-county-neighborhoods-current/",
                "metadata": {"sqmi": 1.84381583493, "type": "unincorporated-area", "name": "Westmont", "slug": "westmont"},
                "resource_uri": "/1.0/boundary/westmont-la-county-neighborhood-current/"
            },
            "geometry": { "type": "Polygon", "coordinates": [  
                [ -118.292472989872849, 33.95951400322592 ], 
                [ -118.291595982569675, 33.959495004635755 ], 
                [ -118.291524972104938, 33.930962005655957 ], 
                [ -118.317752979089761, 33.930901001647982 ], 
                [ -118.317719982513182, 33.94546299957149 ], 
                [ -118.313371983162199, 33.945460004723991 ], 
                [ -118.313386989551688, 33.938214000142573 ], 
                [ -118.30902499719825, 33.938210004721995 ], 
                [ -118.309014974916209, 33.941833000143951 ], 
                [ -118.305190995504958, 33.941845002911577 ], 
                [ -118.305179974908896, 33.945467000185211 ], 
                [ -118.302453995362868, 33.945474003461399 ], 
                [ -118.302447974911544, 33.949993000109373 ], 
                [ -118.300261995361026, 33.949999003468804 ], 
                [ -118.300266974796259, 33.959481001336009 ], 
                [ -118.292472989872849, 33.95951400322592 ] 
             ] }
        }
    ]
}

polygons = []

for feat in file['features']:
    polygon = Polygon([ (coor[0], coor[1]) for coor in  feat['geometry']['coordinates'] ])
    polygons.append(polygon)

new_geometry = mapping(cascaded_union(polygons)) # This line merges the polygones

new_feature = dict(type='Feature', id="", properties=dict(Name=""),geometry=dict(type=new_geometry['type'], coordinates=new_geometry['coordinates']))

outjson = dict(type='FeatureCollection', features=[new_feature])

encoder = JSONEncoder(separators=(',', ':'))
encoded = encoder.iterencode(outjson)

# output = outfile

for token in encoded:
    print(token)
# Out:
# {
# "type"
# :
# "FeatureCollection"
# ,
# "features"
# :
# [
# {
# "type"
# :
# "Feature"
# ,
# "id"
# :
# ""
# ,
# "properties"
# :
# {
# "Name"
# :
# ""
# }
# ,
# "geometry"
# :
# {
# "type"
# :
# "Polygon"
# ,
# "coordinates"
# :
# [
# [
# [-118.29152497210494
# ,33.93096200565596
# ]
# ,
# [-118.29160698235776
# ,33.91642200621436
# ]
# ,
# [-118.31391298047903
# ,33.91645200007503
# ]
# ,
# [-118.31398199285357
# ,33.91836100381049
# ]
# ,
# [-118.31520998502528
# ,33.91843399843815
# ]
# ,
# [-118.31648398731515
# ,33.91765600546545
# ]
# ,
# [-118.31778797898059
# ,33.91752000315647
# ]
# ,
# [-118.31776897986255
# ,33.92160600576327
# ]
# ,
# [-118.31339099241845
# ,33.9234099992319
# ]
# ,
# [-118.31339198594485
# ,33.93091114492958
# ]
# ,
# [-118.31775297908976
# ,33.93090100164798
# ]
# ,
# [-118.31771998251318
# ,33.94546299957149
# ]
# ,
# [-118.3133719831622
# ,33.94546000472399
# ]
# ,
# [-118.31338698955169
# ,33.93821400014257
# ]
# ,
# [-118.30902499719825
# ,33.938210004721995
# ]
# ,
# [-118.30901497491621
# ,33.94183300014395
# ]
# ,
# [-118.30519099550496
# ,33.94184500291158
# ]
# ,
# [-118.3051799749089
# ,33.94546700018521
# ]
# ,
# [-118.30245399536287
# ,33.9454740034614
# ]
# ,
# [-118.30244797491154
# ,33.94999300010937
# ]
# ,
# [-118.30026199536103
# ,33.949999003468804
# ]
# ,
# [-118.30026697479626
# ,33.95948100133601
# ]
# ,
# [-118.29247298987285
# ,33.95951400322592
# ]
# ,
# [-118.29159598256967
# ,33.959495004635755
# ]
# ,
# [-118.29152497210494
# ,33.93096200565596
# ]
# ]
# ]
# }
# }
# ]
# }

# %%
import json

with open('the-stack/test.geojson', 'r') as f:
    data = json.load(f)

#A Python dictionary containing properties to be added to each GeoJSON Feature
properties_dict={
    "cases": None,
    "population": None
    }
#Convert the dictionary to a list
# properties_list=zip(properties_dict.keys(),properties_dict.values())

#Loop over GeoJSON features and add the new properties
for feat in data['features']:
#     for i in range(len(properties_list)):
    feat['properties'].update(properties_dict)
#         feat ['properties'][properties_list[i][0]]=properties_list[i][1]

#Write result to a new file
with open('the-stack/output.geojson', 'w') as f:
    json.dump(data, f, indent=4)
