# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('data.csv')
df
# Out:
#       entry_term_cd entry_year_trailing_summer_7 admit_level  \
# 0               18F                      2018-19    Freshman
# 1               18F                      2018-19    Freshman
# 2               18F                      2018-19    Freshman
# 3               18F                      2018-19    Freshman
# 4               18F                      2018-19    Freshman
# ...             ...                          ...         ...
# 12915           18F                      2018-19    Transfer
# 12916           18F                      2018-19    Transfer
# 12917           18F                      2018-19    Transfer
# 12918           18F                      2018-19    Transfer
# 12919           18F                      2018-19    Transfer
#
#                                              start_major  \
# 0      ANTHROPOLOGY                                  ...
# 1      APPLIED MATHEMATICS                           ...
# 2      BIOCHEMISTRY                                  ...
# 3      BIOCHEMISTRY                                  ...
# 4      BIOLOGY                                       ...
# ...                                                  ...
# 12915  POLITICAL SCIENCE                             ...
# 12916  POLITICAL SCIENCE                             ...
# 12917  PSYCHOBIOLOGY                                 ...
# 12918  SOCIOLOGY                                     ...
# 12919  SOCIOLOGY                                     ...
#
#                                                end_major    end_status  \
# 0      ANTHROPOLOGY-BS                               ...      Enrolled
# 1      FINANCIAL ACTUARIAL MATHEMATICS               ...      Enrolled
# 2      POLITICAL SCIENCE                             ...      Enrolled
# 3      PSYCHOLOGY                                    ...      Enrolled
# 4      MATERIALS ENGINEERING                         ...      Enrolled
# ...                                                  ...           ...
# 12915  LINGUISTICS                                   ...      Enrolled
# 12916  POLITICAL SCIENCE                             ...     Graduated
# 12917  PSYCHOBIOLOGY                                 ...     Graduated
# 12918                                       Not Enrolled  Not Enrolled
# 12919  SOCIOLOGY                                     ...     Graduated
#
#                 section headcount
# 0      Fall 1 to Fall 2       <10
# 1      Fall 1 to Fall 2       <10
# 2      Fall 1 to Fall 2       <10
# 3      Fall 1 to Fall 2       <10
# 4      Fall 1 to Fall 2       <10
# ...                 ...       ...
# 12915  Fall 5 to Fall 6       <10
# 12916  Fall 5 to Fall 6       <10
# 12917  Fall 5 to Fall 6       <10
# 12918  Fall 5 to Fall 6       <10
# 12919  Fall 5 to Fall 6       <10
#
# [12920 rows x 8 columns]

# %%
majors1 = df['start_major'].tolist()
majors2 = df['end_major'].tolist()
sum_majors = majors1 + majors2
all_majors = list(set(sum_majors))
all_majors
# Out:
# ['LINGUISTICS AND ENGLISH                                                                                                 ',
#  'FILM AND TELEVISION                                                                                                     ',
#  'INTERNATIONAL DEVELOPMENT STUDIES                           ',
#  'BIOCHEMISTRY                                                                                                            ',
#  'DATA THEORY                                                 ',
#  'LINGUISTICS AND ITALIAN                                                                                                 ',
#  'PUBLIC HEALTH                                                                                                           ',
#  'NEUROSCIENCE                                                                                                            ',
#  'HISTORY                                                                                                                 ',
#  'CENTRAL AND EAST EUROPEAN LANGUAGES AND CULTURES                                                                        ',
#  'MATHEMATICS FOR TEACHING                                                                                                ',
#  'MATHEMATICS OF COMPUTATION                                  ',
#  'HUMAN BIOLOGY AND SOCIETY - BS                              ',
#  'GEOGRAPHY/ENVIRONMENTAL STUDIES                                                                                         ',
#  'PHILOSOPHY                                                                                                              ',
#  'RUSSIAN LANGUAGE AND LITERATURE                                                                                         ',
#  'GREEK AND LATIN                                                                                                         ',
#  'MUSIC COMPOSITION                                                                                                       ',
#  'ENGINEERING GEOLOGY                                                                                                     ',
#  'MUSIC EDUCATION                                                                                                         ',
#  'ECONOMICS                                                                                                               ',
#  'MECHANICAL ENGINEERING                                                                                                  ',
#  'JAPANESE                                                                                                                ',
#  'MIDDLE EASTERN STUDIES                                                                                                  ',
#  'GENERAL CHEMISTRY                                                                                                       ',
#  'ANTHROPOLOGY-BS                                                                                                         ',
#  'SPANISH AND PORTUGUESE                                                                                                  ',
#  'LATIN                                                                                                                   ',
#  'ASIAN RELIGIONS                                                                                                         ',
#  'COMPARATIVE LITERATURE                                                                                                  ',
#  'MATHEMATICS                                                                                                             ',
#  'BIOPHYSICS                                                                                                              ',
#  'EUROPEAN LANGUAGES AND TRANSCULTURAL STUDIES WITH GERMAN                                                                ',
#  'ECOLOGY, BEHAVIOR, AND EVOLUTION                                                                                        ',
#  'MICROBIOLOGY, IMMUNOLOGY, AND MOLECULAR GENETICS            ',
#  'AEROSPACE ENGINEERING                                                                                                   ',
#  'EARTH AND ENVIRONMENTAL SCIENCE                                                                                         ',
#  'WORLD ARTS AND CULTURES                                                                                                 ',
#  'EUROPEAN LANGUAGES AND TRANSCULTURAL STUDIES WITH FRENCH AND FRANCOPHONE                                                ',
#  'SOCIOLOGY                                                                                                               ',
#  'CLIMATE SCIENCE                                                                                                         ',
#  'ASIAN AMERICAN STUDIES                                                                                                  ',
#  'MATHEMATICS/APPLIED SCIENCE                                                                                             ',
#  'MUSIC HISTORY AND INDUSTRY                                                                                              ',
#  'ASIAN STUDIES                                                                                                           ',
#  'POLITICAL SCIENCE                                                                                                       ',
#  'SPANISH                                                                                                                 ',
#  'UNDECLARED-LIFE SCIENCE                                                                                                 ',
#  'PUBLIC HEALTH-BA                                                                                                        ',
#  'MATHEMATICS/ECONOMICS                                                                                                   ',
#  'EDUCATION AND SOCIAL TRANSFORMATION                                                                                     ',
#  'LINGUISTICS AND COMPUTER SCIENCE                                                                                        ',
#  'APPLIED LINGUISTICS                                                                                                     ',
#  'PSYCHOLOGY                                                                                                              ',
#  'ART HISTORY                                                                                                             ',
#  'MATHEMATICS OF COMPUTATION                                                                                              ',
#  'UNDECLARED-SOCIAL SCIENCE                                                                                               ',
#  'EDUCATION AND SOCIAL TRANSFORMATION                         ',
#  'HISTORY                                                     ',
#  'APPLIED MATHEMATICS                                                                                                     ',
#  'PSYCHOBIOLOGY                                               ',
#  'HUMAN BIOLOGY AND SOCIETY - BA                                                                                          ',
#  'MOLECULAR, CELL, AND DEVELOPMENTAL BIOLOGY                                                                              ',
#  'COMPUTER SCIENCE AND ENGINEERING                                                                                        ',
#  'SPANISH AND COMMUNITY AND CULTURE                                                                                       ',
#  'LINGUISTICS AND SPANISH                                                                                                 ',
#  'FRENCH AND LINGUISTICS                                                                                                  ',
#  'AFRICAN AMERICAN STUDIES                                                                                                ',
#  'EUROPEAN STUDIES                                                                                                        ',
#  'GLOBAL STUDIES                                              ',
#  'LINGUISTICS AND PSYCHOLOGY                                                                                              ',
#  'ATMOSPHERIC AND OCEANIC SCIENCES/MATHEMATICS                                                                            ',
#  'Not Enrolled',
#  'FINANCIAL ACTUARIAL MATHEMATICS                                                                                         ',
#  'CHEMISTRY                                                                                                               ',
#  'PUBLIC HEALTH-BA                                            ',
#  'ENVIRONMENTAL SCIENCE                                                                                                   ',
#  'MATHEMATICS/APPLIED SCIENCE                                 ',
#  'LINGUISTICS AND ASIAN LANGUAGES AND CULTURES                                                                            ',
#  'ARCHITECTURAL STUDIES                                                                                                   ',
#  'LATIN AMERICAN STUDIES                                                                                                  ',
#  'LINGUISTICS AND FRENCH                                                                                                  ',
#  'COMPUTER ENGINEERING                                                                                                    ',
#  'COGNITIVE SCIENCE                                           ',
#  'HUMAN BIOLOGY AND SOCIETY - BA                              ',
#  'CIVIL ENGINEERING                                                                                                       ',
#  'PHYSICS                                                                                                                 ',
#  'MATHEMATICS FOR TEACHING                                    ',
#  'MUSICOLOGY                                                                                                              ',
#  'PHYSICS-BA                                                                                                              ',
#  'MATERIALS ENGINEERING                                                                                                   ',
#  'LINGUISTICS AND PHILOSOPHY                                                                                              ',
#  'LATIN AMERICAN STUDIES                                      ',
#  'ELECTRICAL ENGINEERING                                                                                                  ',
#  'ETHNOMUSICOLOGY                                                                                                         ',
#  'GEOLOGY                                                                                                                 ',
#  'ATMOSPHERIC AND OCEANIC SCIENCES                                                                                        ',
#  'INDIVIDUAL FIELD OF CONCENTRATION                                                                                       ',
#  'COMPUTER SCIENCE                                                                                                        ',
#  'CHINESE                                                                                                                 ',
#  'EUROPEAN LANGUAGES AND TRANSCULTURAL STUDIES WITH ITALIAN                                                               ',
#  'STATISTICS AND DATA SCIENCE                                                                                             ',
#  'UNDECLARED-ENGINEERING AND APPLIED SCIENCE                                                                              ',
#  'PUBLIC AFFAIRS                                              ',
#  'BUSINESS ECONOMICS                                          ',
#  'AMERICAN INDIAN STUDIES                                                                                                 ',
#  'LINGUISTICS AND ANTHROPOLOGY                                                                                            ',
#  'COMMUNICATION                                                                                                           ',
#  'CHICANA AND CHICANO STUDIES                                                                                             ',
#  'STUDY OF RELIGION                                                                                                       ',
#  'AFRICAN AND MIDDLE EASTERN STUDIES                                                                                      ',
#  'UNDECLARED-HUMANITIES                                                                                                   ',
#  'DANCE                                                                                                                   ',
#  'HUMAN BIOLOGY AND SOCIETY - BS                                                                                          ',
#  'SPANISH AND LINGUISTICS                                                                                                 ',
#  'MUSIC PERFORMANCE                                                                                                       ',
#  'ASIAN STUDIES                                               ',
#  'ANCIENT NEAR EAST AND EGYPTOLOGY                                                                                        ',
#  'MICROBIOLOGY, IMMUNOLOGY, AND MOLECULAR GENETICS                                                                        ',
#  'ANTHROPOLOGY                                                                                                            ',
#  'COMPUTATIONAL AND SYSTEMS BIOLOGY                           ',
#  'JEWISH STUDIES                                                                                                          ',
#  'MATHEMATICS                                                 ',
#  'LINGUISTICS AND SCANDINAVIAN LANGUAGES                                                                                  ',
#  'FINANCIAL ACTUARIAL MATHEMATICS                             ',
#  'COGNITIVE SCIENCE                                                                                                       ',
#  'ASIAN LANGUAGES AND LINGUISTICS                                                                                         ',
#  'GEOPHYSICS                                                                                                              ',
#  'CHEMISTRY/MATERIALS SCIENCE                                                                                             ',
#  'AFRICAN AND MIDDLE EASTERN STUDIES                          ',
#  'PUBLIC HEALTH                                               ',
#  'AMERICAN LITERATURE AND CULTURE                                                                                         ',
#  'DESIGN / MEDIA ARTS                                                                                                     ',
#  'ARABIC                                                                                                                  ',
#  'ENGLISH                                                                                                                 ',
#  'CLASSICAL CIVILIZATION                                                                                                  ',
#  'COMPUTATIONAL AND SYSTEMS BIOLOGY                                                                                       ',
#  'EUROPEAN LANGUAGES AND TRANSCULTURAL STUDIES                                                                            ',
#  'LABOR STUDIES                                                                                                           ',
#  'SOCIOLOGY                                                   ',
#  'LINGUISTICS                                                                                                             ',
#  'ART                                                                                                                     ',
#  'ASTROPHYSICS                                                                                                            ',
#  'IRANIAN STUDIES                                                                                                         ',
#  'APPLIED MATHEMATICS                                         ',
#  'STATISTICS AND DATA SCIENCE                                 ',
#  'BUSINESS ECONOMICS                                                                                                      ',
#  'RUSSIAN STUDIES                                                                                                         ',
#  'ITALIAN AND SPECIAL FIELDS                                                                                              ',
#  'THEATER                                                                                                                 ',
#  'GENDER STUDIES                                                                                                          ',
#  'UNDECLARED                                                                                                              ',
#  'GLOBAL JAZZ STUDIES                                                                                                     ',
#  'NURSING-PRELICENSURE                                                                                                    ',
#  'BIOLOGY                                                                                                                 ',
#  'GLOBAL STUDIES                                                                                                          ',
#  'PUBLIC AFFAIRS                                                                                                          ',
#  'MUSIC INDUSTRY                                                                                                          ',
#  'PSYCHOBIOLOGY                                                                                                           ',
#  'GEOGRAPHY                                                                                                               ',
#  'NORDIC STUDIES                                                                                                          ',
#  'INTERNATIONAL DEVELOPMENT STUDIES                                                                                       ',
#  'UNDECLARED-PHYSICAL SCIENCE                                                                                             ',
#  'ECONOMICS                                                   ',
#  'MATHEMATICS/ECONOMICS                                       ',
#  'EUROPEAN STUDIES                                            ',
#  'PHYSIOLOGICAL SCIENCE                                                                                                   ',
#  'ASIAN HUMANITIES                                                                                                        ',
#  'KOREAN                                                                                                                  ',
#  'MUSIC                                                                                                                   ',
#  'DATA THEORY                                                                                                             ',
#  'POLITICAL SCIENCE                                           ',
#  'CHEMICAL ENGINEERING                                                                                                    ',
#  'PSYCHOLOGY                                                  ',
#  'BIOENGINEERING                                                                                                          ',
#  'MARINE BIOLOGY                                                                                                          ']

# %%
# Check if "banana" is in the list
if 'HUMAN BIOLOGY AND SOCIETY - BS                              ' in all_majors:
    print("Yes, 'banana' is in the list.")
else:
    print("No, 'banana' is not in the list.")
# Out:
# Yes, 'banana' is in the list.

# %%
import csv

students = []
with open('data.csv', mode = 'r') as file:
    csv_reader = csv.DictReader(file)
    for row in csv_reader:
        new_dict = {
            'start_major' : row['start_major'],
            'end_major' : row['end_major'],
            'headcount' : row['headcount']
        }
        students.append(new_dict)

students
# Out:
# [{'start_major': 'ANTHROPOLOGY                                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'APPLIED MATHEMATICS                                         ',
#   'end_major': '<10'},
#  {'start_major': 'BIOCHEMISTRY                                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'BIOCHEMISTRY                                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'BIOLOGY                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'BUSINESS ECONOMICS                                          ',
#   'end_major': '<10'},
#  {'start_major': 'CIVIL ENGINEERING                                                                                                       ',
#   'end_major': '<10'},
#  {'start_major': 'CLIMATE SCIENCE                                                                                                         ',
#   'end_major': '<10'},
#  {'start_major': 'COGNITIVE SCIENCE                                           ',
#   'end_major': '<10'},
#  {'start_major': 'ECOLOGY, BEHAVIOR, AND EVOLUTION                                                                                        ',
#   'end_major': '<10'},
#  {'start_major': 'ECONOMICS                                                   ',
#   'end_major': '<10'},
#  {'start_major': 'ELECTRICAL ENGINEERING                                                                                                  ',
#   'end_major': '<10'},
#  {'start_major': 'ELECTRICAL ENGINEERING                                                                                                  ',
#   'end_major': '<10'},
#  {'start_major': 'ENGINEERING GEOLOGY                                                                                                     ',
#   'end_major': '<10'},
#  {'start_major': 'ENGLISH                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'ETHNOMUSICOLOGY                                                                                                         ',
#   'end_major': '<10'},
#  {'start_major': 'FINANCIAL ACTUARIAL MATHEMATICS                             ',
#   'end_major': '<10'},
#  {'start_major': 'FINANCIAL ACTUARIAL MATHEMATICS                             ',
#   'end_major': '<10'},
#  {'start_major': 'GLOBAL STUDIES                                              ',
#   'end_major': '<10'},
#  {'start_major': 'HUMAN BIOLOGY AND SOCIETY - BA                              ',
#   'end_major': '<10'},
#  {'start_major': 'INTERNATIONAL DEVELOPMENT STUDIES                           ',
#   'end_major': '<10'},
#  {'start_major': 'INTERNATIONAL DEVELOPMENT STUDIES                           ',
#   'end_major': '<10'},
#  {'start_major': 'LINGUISTICS AND ANTHROPOLOGY                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'MATERIALS ENGINEERING                                                                                                   ',
#   'end_major': '<10'},
#  {'start_major': 'MATERIALS ENGINEERING                                                                                                   ',
#   'end_major': '<10'},
#  {'start_major': 'MATHEMATICS OF COMPUTATION                                  ',
#   'end_major': '<10'},
#  {'start_major': 'MATHEMATICS/ECONOMICS                                       ',
#   'end_major': '39'},
#  {'start_major': 'MECHANICAL ENGINEERING                                                                                                  ',
#   'end_major': '<10'},
#  {'start_major': 'MECHANICAL ENGINEERING                                                                                                  ',
#   'end_major': '<10'},
#  {'start_major': 'MECHANICAL ENGINEERING                                                                                                  ',
#   'end_major': '<10'},
#  {'start_major': 'MECHANICAL ENGINEERING                                                                                                  ',
#   'end_major': '<10'},
#  {'start_major': 'MICROBIOLOGY, IMMUNOLOGY, AND MOLECULAR GENETICS            ',
#   'end_major': '<10'},
#  {'start_major': 'AMERICAN INDIAN STUDIES                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'ANTHROPOLOGY-BS                                                                                                         ',
#   'end_major': '<10'},
#  {'start_major': 'APPLIED MATHEMATICS                                         ',
#   'end_major': '<10'},
#  {'start_major': 'APPLIED MATHEMATICS                                         ',
#   'end_major': '<10'},
#  {'start_major': 'ART                                                                                                                     ',
#   'end_major': '<10'},
#  {'start_major': 'ASIAN LANGUAGES AND LINGUISTICS                                                                                         ',
#   'end_major': '<10'},
#  {'start_major': 'ASTROPHYSICS                                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'ASTROPHYSICS                                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'BIOCHEMISTRY                                                                                                            ',
#   'end_major': '13'},
#  {'start_major': 'BIOCHEMISTRY                                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'BIOENGINEERING                                                                                                          ',
#   'end_major': '<10'},
#  {'start_major': 'BIOENGINEERING                                                                                                          ',
#   'end_major': '<10'},
#  {'start_major': 'BIOLOGY                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'BIOLOGY                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'BIOPHYSICS                                                                                                              ',
#   'end_major': '<10'},
#  {'start_major': 'BUSINESS ECONOMICS                                          ',
#   'end_major': '<10'},
#  {'start_major': 'CHEMISTRY                                                                                                               ',
#   'end_major': '<10'},
#  {'start_major': 'CIVIL ENGINEERING                                                                                                       ',
#   'end_major': '81'},
#  {'start_major': 'COGNITIVE SCIENCE                                           ',
#   'end_major': '<10'},
#  {'start_major': 'COMPUTER SCIENCE AND ENGINEERING                                                                                        ',
#   'end_major': '<10'},
#  {'start_major': 'DESIGN / MEDIA ARTS                                                                                                     ',
#   'end_major': '24'},
#  {'start_major': 'ECONOMICS                                                   ',
#   'end_major': '<10'},
#  {'start_major': 'ECONOMICS                                                   ',
#   'end_major': '<10'},
#  {'start_major': 'ECONOMICS                                                   ',
#   'end_major': '<10'},
#  {'start_major': 'ELECTRICAL ENGINEERING                                                                                                  ',
#   'end_major': '<10'},
#  {'start_major': 'FINANCIAL ACTUARIAL MATHEMATICS                             ',
#   'end_major': '<10'},
#  {'start_major': 'FINANCIAL ACTUARIAL MATHEMATICS                             ',
#   'end_major': '44'},
#  {'start_major': 'GEOLOGY                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'GEOPHYSICS                                                                                                              ',
#   'end_major': '<10'},
#  {'start_major': 'HUMAN BIOLOGY AND SOCIETY - BS                              ',
#   'end_major': '<10'},
#  {'start_major': 'HUMAN BIOLOGY AND SOCIETY - BS                              ',
#   'end_major': '<10'},
#  {'start_major': 'LINGUISTICS AND PSYCHOLOGY                                                                                              ',
#   'end_major': '<10'},
#  {'start_major': 'AEROSPACE ENGINEERING                                                                                                   ',
#   'end_major': '<10'},
#  {'start_major': 'APPLIED MATHEMATICS                                         ',
#   'end_major': '<10'},
#  {'start_major': 'APPLIED MATHEMATICS                                         ',
#   'end_major': '<10'},
#  {'start_major': 'APPLIED MATHEMATICS                                         ',
#   'end_major': '<10'},
#  {'start_major': 'ART                                                                                                                     ',
#   'end_major': '46'},
#  {'start_major': 'ART                                                                                                                     ',
#   'end_major': '<10'},
#  {'start_major': 'BIOCHEMISTRY                                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'BIOLOGY                                                                                                                 ',
#   'end_major': '16'},
#  {'start_major': 'BIOLOGY                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'BIOPHYSICS                                                                                                              ',
#   'end_major': '<10'},
#  {'start_major': 'BUSINESS ECONOMICS                                          ',
#   'end_major': '<10'},
#  {'start_major': 'CHEMICAL ENGINEERING                                                                                                    ',
#   'end_major': '<10'},
#  {'start_major': 'CHINESE                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'CIVIL ENGINEERING                                                                                                       ',
#   'end_major': '<10'},
#  {'start_major': 'CIVIL ENGINEERING                                                                                                       ',
#   'end_major': '<10'},
#  {'start_major': 'COGNITIVE SCIENCE                                           ',
#   'end_major': '<10'},
#  {'start_major': 'ENGLISH                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'ENVIRONMENTAL SCIENCE                                                                                                   ',
#   'end_major': '<10'},
#  {'start_major': 'ENVIRONMENTAL SCIENCE                                                                                                   ',
#   'end_major': '<10'},
#  {'start_major': 'HUMAN BIOLOGY AND SOCIETY - BS                              ',
#   'end_major': '<10'},
#  {'start_major': 'HUMAN BIOLOGY AND SOCIETY - BS                              ',
#   'end_major': '<10'},
#  {'start_major': 'LINGUISTICS AND PSYCHOLOGY                                                                                              ',
#   'end_major': '<10'},
#  {'start_major': 'LINGUISTICS AND PSYCHOLOGY                                                                                              ',
#   'end_major': '<10'},
#  {'start_major': 'MATHEMATICS                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'MATHEMATICS                                                 ',
#   'end_major': '65'},
#  {'start_major': 'MATHEMATICS OF COMPUTATION                                  ',
#   'end_major': '<10'},
#  {'start_major': 'MATHEMATICS/APPLIED SCIENCE                                 ',
#   'end_major': '<10'},
#  {'start_major': 'MATHEMATICS/ECONOMICS                                       ',
#   'end_major': '<10'},
#  {'start_major': 'MICROBIOLOGY, IMMUNOLOGY, AND MOLECULAR GENETICS            ',
#   'end_major': '<10'},
#  {'start_major': 'MICROBIOLOGY, IMMUNOLOGY, AND MOLECULAR GENETICS            ',
#   'end_major': '<10'},
#  {'start_major': 'MOLECULAR, CELL, AND DEVELOPMENTAL BIOLOGY                                                                              ',
#   'end_major': '<10'},
#  {'start_major': 'MUSIC EDUCATION                                                                                                         ',
#   'end_major': '<10'},
#  {'start_major': 'MUSIC EDUCATION                                                                                                         ',
#   'end_major': '<10'},
#  {'start_major': 'ANTHROPOLOGY                                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'ART                                                                                                                     ',
#   'end_major': '<10'},
#  {'start_major': 'ASIAN AMERICAN STUDIES                                                                                                  ',
#   'end_major': '<10'},
#  {'start_major': 'ATMOSPHERIC AND OCEANIC SCIENCES                                                                                        ',
#   'end_major': '<10'},
#  {'start_major': 'BIOCHEMISTRY                                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'BIOCHEMISTRY                                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'BIOCHEMISTRY                                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'BIOCHEMISTRY                                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'BIOENGINEERING                                                                                                          ',
#   'end_major': '<10'},
#  {'start_major': 'BIOLOGY                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'BUSINESS ECONOMICS                                          ',
#   'end_major': '<10'},
#  {'start_major': 'CHEMISTRY                                                                                                               ',
#   'end_major': '15'},
#  {'start_major': 'CHEMISTRY                                                                                                               ',
#   'end_major': '<10'},
#  {'start_major': 'CLASSICAL CIVILIZATION                                                                                                  ',
#   'end_major': '<10'},
#  {'start_major': 'EARTH AND ENVIRONMENTAL SCIENCE                                                                                         ',
#   'end_major': '<10'},
#  {'start_major': 'ENGLISH                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'FINANCIAL ACTUARIAL MATHEMATICS                             ',
#   'end_major': '<10'},
#  {'start_major': 'GLOBAL STUDIES                                              ',
#   'end_major': '<10'},
#  {'start_major': 'GLOBAL STUDIES                                              ',
#   'end_major': '<10'},
#  {'start_major': 'GLOBAL STUDIES                                              ',
#   'end_major': '<10'},
#  {'start_major': 'HUMAN BIOLOGY AND SOCIETY - BS                              ',
#   'end_major': '<10'},
#  {'start_major': 'LINGUISTICS AND COMPUTER SCIENCE                                                                                        ',
#   'end_major': '<10'},
#  {'start_major': 'LINGUISTICS AND COMPUTER SCIENCE                                                                                        ',
#   'end_major': '<10'},
#  {'start_major': 'MATHEMATICS/APPLIED SCIENCE                                 ',
#   'end_major': '<10'},
#  {'start_major': 'MICROBIOLOGY, IMMUNOLOGY, AND MOLECULAR GENETICS            ',
#   'end_major': '<10'},
#  {'start_major': 'MICROBIOLOGY, IMMUNOLOGY, AND MOLECULAR GENETICS            ',
#   'end_major': '<10'},
#  {'start_major': 'MOLECULAR, CELL, AND DEVELOPMENTAL BIOLOGY                                                                              ',
#   'end_major': '<10'},
#  {'start_major': 'MOLECULAR, CELL, AND DEVELOPMENTAL BIOLOGY                                                                              ',
#   'end_major': '<10'},
#  {'start_major': 'NEUROSCIENCE                                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'NEUROSCIENCE                                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'AEROSPACE ENGINEERING                                                                                                   ',
#   'end_major': '<10'},
#  {'start_major': 'APPLIED MATHEMATICS                                         ',
#   'end_major': '<10'},
#  {'start_major': 'ARABIC                                                                                                                  ',
#   'end_major': '<10'},
#  {'start_major': 'BIOCHEMISTRY                                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'BIOLOGY                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'BIOLOGY                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'BIOPHYSICS                                                                                                              ',
#   'end_major': '<10'},
#  {'start_major': 'CHEMICAL ENGINEERING                                                                                                    ',
#   'end_major': '63'},
#  {'start_major': 'CHEMISTRY                                                                                                               ',
#   'end_major': '<10'},
#  {'start_major': 'CHEMISTRY                                                                                                               ',
#   'end_major': '<10'},
#  {'start_major': 'CHEMISTRY/MATERIALS SCIENCE                                                                                             ',
#   'end_major': '<10'},
#  {'start_major': 'COGNITIVE SCIENCE                                           ',
#   'end_major': '67'},
#  {'start_major': 'COGNITIVE SCIENCE                                           ',
#   'end_major': '<10'},
#  {'start_major': 'ECONOMICS                                                   ',
#   'end_major': '<10'},
#  {'start_major': 'ENGLISH                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'GEOGRAPHY/ENVIRONMENTAL STUDIES                                                                                         ',
#   'end_major': '<10'},
#  {'start_major': 'HUMAN BIOLOGY AND SOCIETY - BS                              ',
#   'end_major': '<10'},
#  {'start_major': 'INTERNATIONAL DEVELOPMENT STUDIES                           ',
#   'end_major': '<10'},
#  {'start_major': 'JAPANESE                                                                                                                ',
#   'end_major': '<10'},
#  {'start_major': 'LINGUISTICS                                                                                                             ',
#   'end_major': '<10'},
#  {'start_major': 'LINGUISTICS AND PSYCHOLOGY                                                                                              ',
#   'end_major': '<10'},
#  {'start_major': 'MARINE BIOLOGY                                                                                                          ',
#   'end_major': '<10'},
#  {'start_major': 'MATERIALS ENGINEERING                                                                                                   ',
#   'end_major': '39'},
#  {'start_major': 'MATHEMATICS/ECONOMICS                                       ',
#   'end_major': '<10'},
#  {'start_major': 'MUSIC EDUCATION                                                                                                         ',
#   'end_major': '<10'},
#  {'start_major': 'NEUROSCIENCE                                                                                                            ',
#   'end_major': '14'},
#  {'start_major': 'PHYSICS                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'PHYSICS                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'PHYSIOLOGICAL SCIENCE                                                                                                   ',
#   'end_major': '<10'},
#  {'start_major': 'PHYSIOLOGICAL SCIENCE                                                                                                   ',
#   'end_major': '<10'},
#  {'start_major': 'ANTHROPOLOGY-BS                                                                                                         ',
#   'end_major': '<10'},
#  {'start_major': 'ASTROPHYSICS                                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'ATMOSPHERIC AND OCEANIC SCIENCES                                                                                        ',
#   'end_major': '<10'},
#  {'start_major': 'BIOCHEMISTRY                                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'BIOLOGY                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'BIOLOGY                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'BIOLOGY                                                                                                                 ',
#   'end_major': '20'},
#  {'start_major': 'BIOLOGY                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'BUSINESS ECONOMICS                                          ',
#   'end_major': '<10'},
#  {'start_major': 'BUSINESS ECONOMICS                                          ',
#   'end_major': '<10'},
#  {'start_major': 'CHEMISTRY                                                                                                               ',
#   'end_major': '<10'},
#  {'start_major': 'CHEMISTRY                                                                                                               ',
#   'end_major': '<10'},
#  {'start_major': 'CHEMISTRY                                                                                                               ',
#   'end_major': '<10'},
#  {'start_major': 'EARTH AND ENVIRONMENTAL SCIENCE                                                                                         ',
#   'end_major': '<10'},
#  {'start_major': 'ENGLISH                                                                                                                 ',
#   'end_major': '76'},
#  {'start_major': 'ENGLISH                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'ENVIRONMENTAL SCIENCE                                                                                                   ',
#   'end_major': '<10'},
#  {'start_major': 'FINANCIAL ACTUARIAL MATHEMATICS                             ',
#   'end_major': '<10'},
#  {'start_major': 'HUMAN BIOLOGY AND SOCIETY - BS                              ',
#   'end_major': '<10'},
#  {'start_major': 'HUMAN BIOLOGY AND SOCIETY - BS                              ',
#   'end_major': '<10'},
#  {'start_major': 'INTERNATIONAL DEVELOPMENT STUDIES                           ',
#   'end_major': '<10'},
#  {'start_major': 'LINGUISTICS AND PSYCHOLOGY                                                                                              ',
#   'end_major': '<10'},
#  {'start_major': 'MATHEMATICS                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'MATHEMATICS                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'MATHEMATICS/ECONOMICS                                       ',
#   'end_major': '<10'},
#  {'start_major': 'MATHEMATICS/ECONOMICS                                       ',
#   'end_major': '<10'},
#  {'start_major': 'NEUROSCIENCE                                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'NEUROSCIENCE                                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'NEUROSCIENCE                                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'PHILOSOPHY                                                                                                              ',
#   'end_major': '<10'},
#  {'start_major': 'PHILOSOPHY                                                                                                              ',
#   'end_major': '<10'},
#  {'start_major': 'POLITICAL SCIENCE                                           ',
#   'end_major': '<10'},
#  {'start_major': 'ANTHROPOLOGY-BS                                                                                                         ',
#   'end_major': '<10'},
#  {'start_major': 'ANTHROPOLOGY-BS                                                                                                         ',
#   'end_major': '<10'},
#  {'start_major': 'APPLIED MATHEMATICS                                         ',
#   'end_major': '<10'},
#  {'start_major': 'BIOCHEMISTRY                                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'BIOLOGY                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'BUSINESS ECONOMICS                                          ',
#   'end_major': '<10'},
#  {'start_major': 'COGNITIVE SCIENCE                                           ',
#   'end_major': '<10'},
#  {'start_major': 'COMPUTER ENGINEERING                                                                                                    ',
#   'end_major': '<10'},
#  {'start_major': 'COMPUTER SCIENCE                                                                                                        ',
#   'end_major': '<10'},
#  {'start_major': 'COMPUTER SCIENCE                                                                                                        ',
#   'end_major': '<10'},
#  {'start_major': 'ECOLOGY, BEHAVIOR, AND EVOLUTION                                                                                        ',
#   'end_major': '<10'},
#  {'start_major': 'ECONOMICS                                                   ',
#   'end_major': '<10'},
#  {'start_major': 'ELECTRICAL ENGINEERING                                                                                                  ',
#   'end_major': '<10'},
#  {'start_major': 'ENGLISH                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'ENGLISH                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'ENVIRONMENTAL SCIENCE                                                                                                   ',
#   'end_major': '<10'},
#  {'start_major': 'ETHNOMUSICOLOGY                                                                                                         ',
#   'end_major': '<10'},
#  {'start_major': 'EUROPEAN LANGUAGES AND TRANSCULTURAL STUDIES WITH FRENCH AND FRANCOPHONE                                                ',
#   'end_major': '<10'},
#  {'start_major': 'GLOBAL JAZZ STUDIES                                                                                                     ',
#   'end_major': '<10'},
#  {'start_major': 'HUMAN BIOLOGY AND SOCIETY - BS                              ',
#   'end_major': '<10'},
#  {'start_major': 'LINGUISTICS AND ASIAN LANGUAGES AND CULTURES                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'LINGUISTICS AND COMPUTER SCIENCE                                                                                        ',
#   'end_major': '26'},
#  {'start_major': 'LINGUISTICS AND COMPUTER SCIENCE                                                                                        ',
#   'end_major': '<10'},
#  {'start_major': 'MARINE BIOLOGY                                                                                                          ',
#   'end_major': '<10'},
#  {'start_major': 'MARINE BIOLOGY                                                                                                          ',
#   'end_major': '<10'},
#  {'start_major': 'MATHEMATICS OF COMPUTATION                                  ',
#   'end_major': '<10'},
#  {'start_major': 'MATHEMATICS/APPLIED SCIENCE                                 ',
#   'end_major': '<10'},
#  {'start_major': 'MOLECULAR, CELL, AND DEVELOPMENTAL BIOLOGY                                                                              ',
#   'end_major': '<10'},
#  {'start_major': 'NEUROSCIENCE                                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'PHYSICS                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'PHYSIOLOGICAL SCIENCE                                                                                                   ',
#   'end_major': '<10'},
#  {'start_major': 'POLITICAL SCIENCE                                           ',
#   'end_major': '<10'},
#  {'start_major': 'APPLIED MATHEMATICS                                         ',
#   'end_major': '<10'},
#  {'start_major': 'ASTROPHYSICS                                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'BIOLOGY                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'BUSINESS ECONOMICS                                          ',
#   'end_major': '<10'},
#  {'start_major': 'BUSINESS ECONOMICS                                          ',
#   'end_major': '<10'},
#  {'start_major': 'CHEMISTRY                                                                                                               ',
#   'end_major': '<10'},
#  {'start_major': 'CIVIL ENGINEERING                                                                                                       ',
#   'end_major': '<10'},
#  {'start_major': 'COMPARATIVE LITERATURE                                                                                                  ',
#   'end_major': '<10'},
#  {'start_major': 'COMPARATIVE LITERATURE                                                                                                  ',
#   'end_major': '<10'},
#  {'start_major': 'COMPUTER ENGINEERING                                                                                                    ',
#   'end_major': '<10'},
#  {'start_major': 'DANCE                                                                                                                   ',
#   'end_major': '<10'},
#  {'start_major': 'ECONOMICS                                                   ',
#   'end_major': '<10'},
#  {'start_major': 'ENGLISH                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'ENGLISH                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'EUROPEAN LANGUAGES AND TRANSCULTURAL STUDIES WITH GERMAN                                                                ',
#   'end_major': '<10'},
#  {'start_major': 'LINGUISTICS                                                                                                             ',
#   'end_major': '<10'},
#  {'start_major': 'LINGUISTICS AND COMPUTER SCIENCE                                                                                        ',
#   'end_major': '<10'},
#  {'start_major': 'MATHEMATICS                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'MATHEMATICS                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'MATHEMATICS                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'MATHEMATICS FOR TEACHING                                    ',
#   'end_major': '11'},
#  {'start_major': 'MATHEMATICS OF COMPUTATION                                  ',
#   'end_major': '<10'},
#  {'start_major': 'MATHEMATICS OF COMPUTATION                                  ',
#   'end_major': '55'},
#  {'start_major': 'MOLECULAR, CELL, AND DEVELOPMENTAL BIOLOGY                                                                              ',
#   'end_major': '<10'},
#  {'start_major': 'MUSIC                                                                                                                   ',
#   'end_major': '23'},
#  {'start_major': 'NEUROSCIENCE                                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'PHYSICS                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'PHYSIOLOGICAL SCIENCE                                                                                                   ',
#   'end_major': '<10'},
#  {'start_major': 'PHYSIOLOGICAL SCIENCE                                                                                                   ',
#   'end_major': '<10'},
#  {'start_major': 'PHYSIOLOGICAL SCIENCE                                                                                                   ',
#   'end_major': '85'},
#  {'start_major': 'POLITICAL SCIENCE                                           ',
#   'end_major': '<10'},
#  {'start_major': 'PSYCHOLOGY                                                  ',
#   'end_major': '<10'},
#  {'start_major': 'ATMOSPHERIC AND OCEANIC SCIENCES                                                                                        ',
#   'end_major': '<10'},
#  {'start_major': 'BIOENGINEERING                                                                                                          ',
#   'end_major': '<10'},
#  {'start_major': 'BIOLOGY                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'CHEMISTRY/MATERIALS SCIENCE                                                                                             ',
#   'end_major': '<10'},
#  {'start_major': 'COMPUTATIONAL AND SYSTEMS BIOLOGY                           ',
#   'end_major': '28'},
#  {'start_major': 'COMPUTER ENGINEERING                                                                                                    ',
#   'end_major': '17'},
#  {'start_major': 'ELECTRICAL ENGINEERING                                                                                                  ',
#   'end_major': '<10'},
#  {'start_major': 'ENVIRONMENTAL SCIENCE                                                                                                   ',
#   'end_major': '<10'},
#  {'start_major': 'EUROPEAN LANGUAGES AND TRANSCULTURAL STUDIES WITH GERMAN                                                                ',
#   'end_major': '<10'},
#  {'start_major': 'GENDER STUDIES                                                                                                          ',
#   'end_major': '<10'},
#  {'start_major': 'GLOBAL STUDIES                                              ',
#   'end_major': '<10'},
#  {'start_major': 'HUMAN BIOLOGY AND SOCIETY - BS                              ',
#   'end_major': '<10'},
#  {'start_major': 'INTERNATIONAL DEVELOPMENT STUDIES                           ',
#   'end_major': '<10'},
#  {'start_major': 'LINGUISTICS AND COMPUTER SCIENCE                                                                                        ',
#   'end_major': '<10'},
#  {'start_major': 'LINGUISTICS AND SPANISH                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'MARINE BIOLOGY                                                                                                          ',
#   'end_major': '14'},
#  {'start_major': 'MATHEMATICS/APPLIED SCIENCE                                 ',
#   'end_major': '20'},
#  {'start_major': 'MATHEMATICS/ECONOMICS                                       ',
#   'end_major': '<10'},
#  {'start_major': 'MICROBIOLOGY, IMMUNOLOGY, AND MOLECULAR GENETICS            ',
#   'end_major': '<10'},
#  {'start_major': 'MOLECULAR, CELL, AND DEVELOPMENTAL BIOLOGY                                                                              ',
#   'end_major': '<10'},
#  {'start_major': 'MOLECULAR, CELL, AND DEVELOPMENTAL BIOLOGY                                                                              ',
#   'end_major': '<10'},
#  {'start_major': 'NEUROSCIENCE                                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'PHILOSOPHY                                                                                                              ',
#   'end_major': '<10'},
#  {'start_major': 'PHYSICS                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'PHYSICS                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'PHYSIOLOGICAL SCIENCE                                                                                                   ',
#   'end_major': '<10'},
#  {'start_major': 'PSYCHOBIOLOGY                                               ',
#   'end_major': '<10'},
#  {'start_major': 'PSYCHOLOGY                                                  ',
#   'end_major': '200'},
#  {'start_major': 'THEATER                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'UNDECLARED-ENGINEERING AND APPLIED SCIENCE                                                                              ',
#   'end_major': '54'},
#  {'start_major': 'UNDECLARED-LIFE SCIENCE                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'POLITICAL SCIENCE                                           ',
#   'end_major': '<10'},
#  {'start_major': 'POLITICAL SCIENCE                                           ',
#   'end_major': '<10'},
#  {'start_major': 'POLITICAL SCIENCE                                           ',
#   'end_major': '17'},
#  {'start_major': 'PSYCHOBIOLOGY                                               ',
#   'end_major': '<10'},
#  {'start_major': 'PSYCHOLOGY                                                  ',
#   'end_major': '<10'},
#  {'start_major': 'PSYCHOLOGY                                                  ',
#   'end_major': '<10'},
#  {'start_major': 'PUBLIC AFFAIRS                                              ',
#   'end_major': '<10'},
#  {'start_major': 'UNDECLARED-ENGINEERING AND APPLIED SCIENCE                                                                              ',
#   'end_major': '<10'},
#  {'start_major': 'UNDECLARED-LIFE SCIENCE                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'UNDECLARED-PHYSICAL SCIENCE                                                                                             ',
#   'end_major': '<10'},
#  {'start_major': 'UNDECLARED-SOCIAL SCIENCE                                                                                               ',
#   'end_major': '<10'},
#  {'start_major': 'UNDECLARED-SOCIAL SCIENCE                                                                                               ',
#   'end_major': '<10'},
#  {'start_major': 'UNDECLARED-SOCIAL SCIENCE                                                                                               ',
#   'end_major': '<10'},
#  {'start_major': 'UNDECLARED-SOCIAL SCIENCE                                                                                               ',
#   'end_major': '<10'},
#  {'start_major': 'AMERICAN LITERATURE AND CULTURE                                                                                         ',
#   'end_major': '<10'},
#  {'start_major': 'COMMUNICATION                                                                                                           ',
#   'end_major': '86'},
#  {'start_major': 'COMPUTER SCIENCE AND ENGINEERING                                                                                        ',
#   'end_major': '17'},
#  {'start_major': 'EUROPEAN STUDIES                                            ',
#   'end_major': '<10'},
#  {'start_major': 'GENDER STUDIES                                                                                                          ',
#   'end_major': '<10'},
#  {'start_major': 'GENDER STUDIES                                                                                                          ',
#   'end_major': '<10'},
#  {'start_major': 'GLOBAL STUDIES                                              ',
#   'end_major': '<10'},
#  {'start_major': 'LATIN                                                                                                                   ',
#   'end_major': '<10'},
#  {'start_major': 'LINGUISTICS                                                                                                             ',
#   'end_major': '<10'},
#  {'start_major': 'LINGUISTICS AND ANTHROPOLOGY                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'LINGUISTICS AND PSYCHOLOGY                                                                                              ',
#   'end_major': '<10'},
#  {'start_major': 'MATHEMATICS FOR TEACHING                                    ',
#   'end_major': '<10'},
#  {'start_major': 'MATHEMATICS FOR TEACHING                                    ',
#   'end_major': '<10'},
#  {'start_major': 'MECHANICAL ENGINEERING                                                                                                  ',
#   'end_major': '24'},
#  {'start_major': 'NEUROSCIENCE                                                                                                            ',
#   'end_major': '22'},
#  {'start_major': 'POLITICAL SCIENCE                                           ',
#   'end_major': '<10'},
#  {'start_major': 'POLITICAL SCIENCE                                           ',
#   'end_major': '<10'},
#  {'start_major': 'PSYCHOLOGY                                                  ',
#   'end_major': '<10'},
#  {'start_major': 'POLITICAL SCIENCE                                           ',
#   'end_major': '<10'},
#  {'start_major': 'PSYCHOBIOLOGY                                               ',
#   'end_major': '<10'},
#  {'start_major': 'PSYCHOLOGY                                                  ',
#   'end_major': '<10'},
#  {'start_major': 'SOCIOLOGY                                                   ',
#   'end_major': '<10'},
#  {'start_major': 'STATISTICS AND DATA SCIENCE                                 ',
#   'end_major': '<10'},
#  {'start_major': 'UNDECLARED-LIFE SCIENCE                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'UNDECLARED-PHYSICAL SCIENCE                                                                                             ',
#   'end_major': '<10'},
#  {'start_major': 'UNDECLARED-SOCIAL SCIENCE                                                                                               ',
#   'end_major': '<10'},
#  {'start_major': 'UNDECLARED-SOCIAL SCIENCE                                                                                               ',
#   'end_major': '<10'},
#  {'start_major': 'UNDECLARED-SOCIAL SCIENCE                                                                                               ',
#   'end_major': '11'},
#  {'start_major': 'WORLD ARTS AND CULTURES                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'ANTHROPOLOGY                                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'ANTHROPOLOGY                                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'APPLIED LINGUISTICS                                                                                                     ',
#   'end_major': '<10'},
#  {'start_major': 'ASIAN AMERICAN STUDIES                                                                                                  ',
#   'end_major': '<10'},
#  {'start_major': 'ASIAN HUMANITIES                                                                                                        ',
#   'end_major': '12'},
#  {'start_major': 'CHEMISTRY                                                                                                               ',
#   'end_major': '21'},
#  {'start_major': 'CHICANA AND CHICANO STUDIES                                                                                             ',
#   'end_major': '<10'},
# ...
#   'end_major': '<10'},
#  {'start_major': 'HISTORY                                                     ',
#   'end_major': '<10'},
#  {'start_major': 'INTERNATIONAL DEVELOPMENT STUDIES                           ',
#   'end_major': '<10'},
#  {'start_major': 'INTERNATIONAL DEVELOPMENT STUDIES                           ',
#   'end_major': '<10'},
#  {'start_major': 'JAPANESE                                                                                                                ',
#   'end_major': '<10'},
#  {'start_major': 'LINGUISTICS                                                                                                             ',
#   'end_major': '<10'},
#  {'start_major': 'LINGUISTICS                                                                                                             ',
#   'end_major': '<10'},
#  {'start_major': 'LINGUISTICS AND ASIAN LANGUAGES AND CULTURES                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'LINGUISTICS AND PSYCHOLOGY                                                                                              ',
#   'end_major': '<10'},
#  {'start_major': 'MATHEMATICS/ECONOMICS                                       ',
#   'end_major': '<10'},
#  {'start_major': 'SOCIOLOGY                                                   ',
#   'end_major': '<10'},
#  {'start_major': 'AFRICAN AMERICAN STUDIES                                                                                                ',
#   'end_major': '<10'},
#  {'start_major': 'ANTHROPOLOGY                                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'BIOCHEMISTRY                                                                                                            ',
#   'end_major': '179'},
#  {'start_major': 'BIOLOGY                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'BIOLOGY                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'BIOLOGY                                                                                                                 ',
#   'end_major': '16'},
#  {'start_major': 'BIOLOGY                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'BIOPHYSICS                                                                                                              ',
#   'end_major': '<10'},
#  {'start_major': 'BUSINESS ECONOMICS                                          ',
#   'end_major': '<10'},
#  {'start_major': 'BUSINESS ECONOMICS                                          ',
#   'end_major': '<10'},
#  {'start_major': 'CIVIL ENGINEERING                                                                                                       ',
#   'end_major': '<10'},
#  {'start_major': 'COMPUTATIONAL AND SYSTEMS BIOLOGY                           ',
#   'end_major': '<10'},
#  {'start_major': 'COMPUTER ENGINEERING                                                                                                    ',
#   'end_major': '<10'},
#  {'start_major': 'ENVIRONMENTAL SCIENCE                                                                                                   ',
#   'end_major': '<10'},
#  {'start_major': 'ENVIRONMENTAL SCIENCE                                                                                                   ',
#   'end_major': '63'},
#  {'start_major': 'ENVIRONMENTAL SCIENCE                                                                                                   ',
#   'end_major': '<10'},
#  {'start_major': 'GEOGRAPHY                                                                                                               ',
#   'end_major': '<10'},
#  {'start_major': 'HISTORY                                                     ',
#   'end_major': '<10'},
#  {'start_major': 'HUMAN BIOLOGY AND SOCIETY - BA                              ',
#   'end_major': '<10'},
#  {'start_major': 'INTERNATIONAL DEVELOPMENT STUDIES                           ',
#   'end_major': '<10'},
#  {'start_major': 'MATERIALS ENGINEERING                                                                                                   ',
#   'end_major': '<10'},
#  {'start_major': 'MATHEMATICS                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'MATHEMATICS/APPLIED SCIENCE                                 ',
#   'end_major': '<10'},
#  {'start_major': 'MICROBIOLOGY, IMMUNOLOGY, AND MOLECULAR GENETICS                                                                        ',
#   'end_major': '<10'},
#  {'start_major': 'MICROBIOLOGY, IMMUNOLOGY, AND MOLECULAR GENETICS                                                                        ',
#   'end_major': '<10'},
#  {'start_major': 'MICROBIOLOGY, IMMUNOLOGY, AND MOLECULAR GENETICS                                                                        ',
#   'end_major': '<10'},
#  {'start_major': 'MOLECULAR, CELL, AND DEVELOPMENTAL BIOLOGY                                                                              ',
#   'end_major': '<10'},
#  {'start_major': 'COMPUTER ENGINEERING                                                                                                    ',
#   'end_major': '<10'},
#  {'start_major': 'ELECTRICAL ENGINEERING                                                                                                  ',
#   'end_major': '37'},
#  {'start_major': 'GENDER STUDIES                                                                                                          ',
#   'end_major': '<10'},
#  {'start_major': 'GENDER STUDIES                                                                                                          ',
#   'end_major': '<10'},
#  {'start_major': 'GENDER STUDIES                                                                                                          ',
#   'end_major': '<10'},
#  {'start_major': 'GEOGRAPHY/ENVIRONMENTAL STUDIES                                                                                         ',
#   'end_major': '12'},
#  {'start_major': 'JEWISH STUDIES                                                                                                          ',
#   'end_major': '<10'},
#  {'start_major': 'LINGUISTICS                                                                                                             ',
#   'end_major': '<10'},
#  {'start_major': 'MATHEMATICS/APPLIED SCIENCE                                 ',
#   'end_major': '<10'},
#  {'start_major': 'MICROBIOLOGY, IMMUNOLOGY, AND MOLECULAR GENETICS            ',
#   'end_major': '<10'},
#  {'start_major': 'NEUROSCIENCE                                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'NEUROSCIENCE                                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'PHILOSOPHY                                                                                                              ',
#   'end_major': '<10'},
#  {'start_major': 'PHYSICS                                                                                                                 ',
#   'end_major': '13'},
#  {'start_major': 'PHYSICS                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'POLITICAL SCIENCE                                                                                                       ',
#   'end_major': '<10'},
#  {'start_major': 'PSYCHOBIOLOGY                                               ',
#   'end_major': '<10'},
#  {'start_major': 'PSYCHOLOGY                                                  ',
#   'end_major': '<10'},
#  {'start_major': 'PSYCHOLOGY                                                  ',
#   'end_major': '<10'},
#  {'start_major': 'SPANISH                                                                                                                 ',
#   'end_major': '16'},
#  {'start_major': 'AEROSPACE ENGINEERING                                                                                                   ',
#   'end_major': '<10'},
#  {'start_major': 'APPLIED LINGUISTICS                                                                                                     ',
#   'end_major': '<10'},
#  {'start_major': 'APPLIED MATHEMATICS                                         ',
#   'end_major': '<10'},
#  {'start_major': 'ASTROPHYSICS                                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'ASTROPHYSICS                                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'BIOCHEMISTRY                                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'BIOCHEMISTRY                                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'BIOLOGY                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'BIOPHYSICS                                                                                                              ',
#   'end_major': '<10'},
#  {'start_major': 'HISTORY                                                     ',
#   'end_major': '28'},
#  {'start_major': 'LINGUISTICS                                                                                                             ',
#   'end_major': '<10'},
#  {'start_major': 'LINGUISTICS                                                                                                             ',
#   'end_major': '<10'},
#  {'start_major': 'MATHEMATICS/ECONOMICS                                       ',
#   'end_major': '<10'},
#  {'start_major': 'MECHANICAL ENGINEERING                                                                                                  ',
#   'end_major': '<10'},
#  {'start_major': 'MICROBIOLOGY, IMMUNOLOGY, AND MOLECULAR GENETICS            ',
#   'end_major': '109'},
#  {'start_major': 'NEUROSCIENCE                                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'NURSING-PRELICENSURE                                                                                                    ',
#   'end_major': '<10'},
#  {'start_major': 'PHYSICS                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'PHYSIOLOGICAL SCIENCE                                                                                                   ',
#   'end_major': '<10'},
#  {'start_major': 'PHYSIOLOGICAL SCIENCE                                                                                                   ',
#   'end_major': '<10'},
#  {'start_major': 'PSYCHOLOGY                                                  ',
#   'end_major': '<10'},
#  {'start_major': 'SOCIOLOGY                                                   ',
#   'end_major': '<10'},
#  {'start_major': 'UNDECLARED-ENGINEERING AND APPLIED SCIENCE                                                                              ',
#   'end_major': '<10'},
#  {'start_major': 'UNDECLARED-HUMANITIES                                                                                                   ',
#   'end_major': '<10'},
#  {'start_major': 'UNDECLARED-LIFE SCIENCE                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'AMERICAN INDIAN STUDIES                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'ANTHROPOLOGY                                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'APPLIED MATHEMATICS                                         ',
#   'end_major': '42'},
#  {'start_major': 'ARCHITECTURAL STUDIES                                                                                                   ',
#   'end_major': '11'},
#  {'start_major': 'ART HISTORY                                                                                                             ',
#   'end_major': '<10'},
#  {'start_major': 'ART HISTORY                                                                                                             ',
#   'end_major': '<10'},
#  {'start_major': 'ASIAN LANGUAGES AND LINGUISTICS                                                                                         ',
#   'end_major': '<10'},
#  {'start_major': 'ASIAN RELIGIONS                                                                                                         ',
#   'end_major': '<10'},
#  {'start_major': 'ASTROPHYSICS                                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'BUSINESS ECONOMICS                                          ',
#   'end_major': '<10'},
#  {'start_major': 'COMPUTER SCIENCE                                                                                                        ',
#   'end_major': '<10'},
#  {'start_major': 'ENGLISH                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'FINANCIAL ACTUARIAL MATHEMATICS                             ',
#   'end_major': '<10'},
#  {'start_major': 'GENDER STUDIES                                                                                                          ',
#   'end_major': '13'},
#  {'start_major': 'MATHEMATICS                                                 ',
#   'end_major': '19'},
#  {'start_major': 'MATHEMATICS FOR TEACHING                                    ',
#   'end_major': '<10'},
#  {'start_major': 'PHILOSOPHY                                                                                                              ',
#   'end_major': '<10'},
#  {'start_major': 'PHILOSOPHY                                                                                                              ',
#   'end_major': '<10'},
#  {'start_major': 'PHYSIOLOGICAL SCIENCE                                                                                                   ',
#   'end_major': '<10'},
#  {'start_major': 'PHYSIOLOGICAL SCIENCE                                                                                                   ',
#   'end_major': '<10'},
#  {'start_major': 'PSYCHOLOGY                                                  ',
#   'end_major': '<10'},
#  {'start_major': 'RUSSIAN STUDIES                                                                                                         ',
#   'end_major': '<10'},
#  {'start_major': 'STATISTICS AND DATA SCIENCE                                 ',
#   'end_major': '<10'},
#  {'start_major': 'THEATER                                                                                                                 ',
#   'end_major': '<10'},
#  {'start_major': 'APPLIED MATHEMATICS                                         ',
#   'end_major': '<10'},
#  {'start_major': 'BIOCHEMISTRY                                                                                                            ',
#   'end_major': '<10'},
#  {'start_major': 'BIOCHEMISTRY                                                                                                            ',
#   'end_major': '<10'},
#  ...]

# %%
# Initialize a dictionary to store counts for each major transition
major_transitions = {}
# Define all possible majors
# majors = ['major1', 'major2', 'major3', 'major4', 'major5', 'major6', 'major7', 'major8', 'major9', 'major10']
# Initialize counters for each major transition
for start_major in all_majors:
    for end_major in all_majors:
        major_transitions[(start_major, end_major)] = 0
# Iterate over students
for student in students:
    if(headcount == "<10")
    
    start_major = student['start_major']
    end_major = student['end_major']
    major_transitions[(start_major, end_major)] += headcount
# Out:
# {'start_major': 'ANTHROPOLOGY                                                                                                            ', 'end_major': '<10'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/naomisuzuki/Desktop/the-stack/python/posts/stack-major-change/major-change.ipynb Cell 6 line 1
#      <a href='vscode-notebook-cell:/Users/naomisuzuki/Desktop/the-stack/python/posts/stack-major-change/major-change.ipynb#W4sZmlsZQ%3D%3D?line=11'>12</a> end_major = student['end_major']
#      <a href='vscode-notebook-cell:/Users/naomisuzuki/Desktop/the-stack/python/posts/stack-major-change/major-change.ipynb#W4sZmlsZQ%3D%3D?line=12'>13</a> print(student)
# ---> <a href='vscode-notebook-cell:/Users/naomisuzuki/Desktop/the-stack/python/posts/stack-major-change/major-change.ipynb#W4sZmlsZQ%3D%3D?line=13'>14</a> major_transitions[(start_major, end_major)] += headcount
#
# KeyError: ('ANTHROPOLOGY                                                                                                            ', '<10')

# %%
print(major_transitions[('SOCIOLOGY                                                                                                               ', 'SOCIOLOGY                                                                                                               ')])
# Out:
# 31
